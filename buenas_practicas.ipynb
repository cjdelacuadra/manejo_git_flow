# %% [markdown]
# # librerias

# %%
import re
import json
import pandas as pd
from pandas.io.json import json_normalize
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### cargar archivos

# %%
raw_tweets = pd.read_json('farmers-protest-tweets-2021-03-5.json', lines=True)

# %%
#raw_tweets = raw_tweets[raw_tweets['lang']=='en']
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)
# Out:
# Shape:  (419507, 21)
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...       []          []
# 1  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 2  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 3  {'username': 'SukhdevSingh_', 'displayname': '...       []          []
# 4  {'username': 'Davidmu66668113', 'displayname':...       []          []
#
#    replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0           0             0  ...           0  1376739399593910273    en
# 1           0             0  ...           0  1376739306287427584    en
# 2           0             0  ...           0  1376738704128020488    en
# 3           0             1  ...           0  1376738640542400518    en
# 4           0             0  ...           0  1376738579171344386    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3  http://twitter.com/download/android  Twitter for Android
# 4  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    quotedTweet mentionedUsers
# 0         None           None
# 1         None           None
# 2         None           None
# 3         None           None
# 4         None           None
#
# [5 rows x 21 columns]

# %% [markdown]
# ### limpiar datos que no usaremos

# %%
users = json_normalize(raw_tweets['user'])
raw_tweets['dias'] = pd.to_datetime(raw_tweets['date']).dt.date
raw_tweets.drop(['replyCount', 'lang', 'sourceUrl', 'source', 'sourceLabel',
                 'quotedTweet', 'mentionedUsers', 'url', 'media',
                 'retweetedTweet', 'conversationId', 'outlinks', 'tcooutlinks'], axis=1, inplace=True)
users.drop(['description', 'linkTcourl', 'friendsCount', 'followersCount', 
            'verified', 'descriptionUrls', 'profileImageUrl', 'protected', 
            'location', 'profileBannerUrl', 'url', 'rawDescription', 'favouritesCount', 'linkUrl'], axis=1, inplace=True)
#raw_tweets['ususarios'] = users
raw_tweets.head(5)
#users.head(5)
# Out:
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                                                 user  retweetCount  likeCount  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...             0          0
# 1  {'username': 'kaursuk06272818', 'displayname':...             0          0
# 2  {'username': 'kaursuk06272818', 'displayname':...             0          0
# 3  {'username': 'SukhdevSingh_', 'displayname': '...             1          3
# 4  {'username': 'Davidmu66668113', 'displayname':...             0          1
#
#    quoteCount        dias
# 0           0  2021-03-30
# 1           0  2021-03-30
# 2           0  2021-03-30
# 3           0  2021-03-30
# 4           0  2021-03-30

# %%
def main(top, raw_tweets):
    if top == 'tweets':
        fn = top_retweeted
    elif top == 'usuarios':
        fn = top_usuarios
    elif top == 'dias':
        fn = top_dias
    elif top == 'hashtags':
        fn = top_hashtags
    return fn(raw_tweets)

# %%
def top_retweeted(tweets):
    top = tweets.nlargest(10, ['retweetCount'])
    return top

# %%
def top_usuarios(tweets):
    users = json_normalize(tweets['user'])
    users.drop(['description', 'linkTcourl', 'friendsCount', 'followersCount', 
            'verified', 'descriptionUrls', 'profileImageUrl', 'protected', 
            'location', 'profileBannerUrl', 'url', 'rawDescription', 'favouritesCount', 'linkUrl'], axis=1, inplace=True)
    top = users.nlargest(10, ['statusesCount'])
    return top

# %%
def top_dias(tweets):
    top = tweets.pivot_table(index = ['dias'], aggfunc='size')
    scores = sorted(tweets.pivot_table(index = ['dias'], aggfunc='size'),reverse = True)[:10]
    topes = []
    for i in scores:
        for x, y in enumerate(top):
            if y == i:
                topes.append((top.index[x],i))
    return topes

# %%
def top_hashtags(tweets):
    return

# %%
top = main('dias', raw_tweets)
print(top)
# Out:
# [(datetime.date(2021, 2, 3), 83866), (datetime.date(2021, 2, 4), 58607), (datetime.date(2021, 2, 5), 33332), (datetime.date(2021, 2, 2), 28548), (datetime.date(2021, 2, 6), 22420), (datetime.date(2021, 2, 7), 11325), (datetime.date(2021, 2, 9), 9320), (datetime.date(2021, 2, 8), 8920), (datetime.date(2021, 2, 10), 7973), (datetime.date(2021, 2, 11), 5698)]
# [(datetime.date(2021, 2, 3), 83866), (datetime.date(2021, 2, 4), 58607), (datetime.date(2021, 2, 5), 33332), (datetime.date(2021, 2, 2), 28548), (datetime.date(2021, 2, 6), 22420), (datetime.date(2021, 2, 7), 11325), (datetime.date(2021, 2, 9), 9320), (datetime.date(2021, 2, 8), 8920), (datetime.date(2021, 2, 10), 7973), (datetime.date(2021, 2, 11), 5698)]
